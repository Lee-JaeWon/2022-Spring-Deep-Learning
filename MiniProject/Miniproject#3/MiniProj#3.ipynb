# %% [markdown]
# # Miniproject#3 장소 인식

# %% [markdown]
# ## 1.소개
# 딥러닝 및 컴퓨터비전에서 장소 인식은 아래의 단계를 거쳐서 이뤄집니다.
# 1. 이미지에서 장소를 대표하는 하나의 global descriptor를 추출한다.
# 2. 비교하려는 이미지 간에 global descriptor 사이의 유사도를 비교하여 가장 유사도가 높은 이미지로 장소를 찾아낸다.
#
# 이번 프로젝트는 각자의 방법으로 global descriptor를 비교해 장소인식을 구현하는 것입니다. 예제로 convolutional autoencoder,vgg16의 CNN 구조에 FC레이어를 추가한 모델의 출력으로 global descriptor를 만드는 것입니다.
# 이렇게 만든 같은 장소의 global descriptor들은 이미지를 찍은 시점, 계절, 빛의 세기에 관계없이 유사도가 가장 높아지는 것을 목표로 합니다.
#
# 이번에 사용할 데이터셋은 이미지를 찍은 시점, 빛의 세기는 같지만, 계절이 여름과 가을로 다른 장소 이미지를 사용합니다. 이미지를 직접 가져와서 확인해봅시다.

# %% [markdown]
# ## 2.먼저 구글드라이브와 colab을 연동해봅시다.

# %% [markdown]
# 아래의 코드를 실행하여 이미지를 로드합니다.

# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
if os.getcwd() != '/content/drive/My Drive':
    os.chdir('./drive/My Drive')

# %% [markdown]
#     Mounted at /content/drive/
# 라는 문구가 나왔다면 성공입니다.아래의 명령어를 실행하여
#
#     /content/drive/My Drive
# 이 나왔는지 확인해주세요

# %%
# !pwd

# %% [markdown]
# ## 3.train set으로 이미지와 이름확인하기

# %% [markdown]
# 일단 train set을 모두 가져옵니다. google drive에 **'place_recognition'** 폴더를 만들고 업로드한 파일의 압축을 풀어주시길 바랍니다.

# %%
import numpy as np

train_summer = np.load("./place_recognition/summer_train_150.npy")
train_fall = np.load("./place_recognition/fall_train_150.npy")
print("summer image shape is ", train_summer.shape)
print("fall image shape is ", train_fall.shape)

# %% [markdown]
# 이제 해당 이미지들을 확인합니다.

# %%
import matplotlib.pyplot as plt
import cv2
def draw_place_image(summer_images, fall_images, image_index):
    fig =plt.figure()
    fig.set_size_inches(15,10.5,forward=True)
    rows=1
    cols=2
    if image_index >=3000:
        image_index =2999
    #저장된 이미지는 vgg16의 입력 이미지와 같은 BGR채널을 가지는 이미지입니다. 
    #해당이미지를 RGB이미지로 변환하여 확인합니다.
    RGB_summer_image =cv2.cvtColor(summer_images[image_index], cv2.COLOR_BGR2RGB)
    RGB_fall_image =cv2.cvtColor(fall_images[image_index], cv2.COLOR_BGR2RGB)
    ax1 = fig.add_subplot(rows,cols,1)
    ax1.imshow(RGB_summer_image)
    ax1.set_title('Summer Image['+str(image_index)+"]",fontsize=20)
    ax1.axis("off")

    ax2 = fig.add_subplot(rows,cols,2)
    ax2.imshow(RGB_fall_image)
    ax2.set_title('Fall Image['+str(image_index)+"]",fontsize=20)
    ax2.axis("off")

draw_place_image(train_summer, train_fall, 25)

# %% [markdown]
# 오른쪽 이미지가 좀더 가을 계절처럼 보이나요?

# %% [markdown]
# ## 4.불러온 이미지 전처리

# %% [markdown]
# 이제 불러온 이미지를 모델의 입력으로 넣을 수 있게 끔 아래의 과정을 진행해야합니다.
# - 이미지를 BGR이미지로 변환
# - 0과 255 사이에서 0과 1사이의 값으로 변환
#
# 첫 번째인 BGR이미지 변환은 이미되어있고 , 아래의 코드를 실행하여 이미지를 0과 1사이의 값으로 바꿉니다.

# %%
train_summer = train_summer / 255.0
train_fall = train_fall/255.0

# %% [markdown]
# ## 5.Convolutional Autoencoder(CAE)를 통한 descriptor 추출

# %% [markdown]
# CAE는 입력된 데이터를 압축하는 모델로 데이터의 특징을 추출할 수 있는 기능, 압축에의한 손실, 사람의 개입이 없는 자동학습이라는 특징을 가지고 있습니다. 아래의 링크를 통해서 자세한 정보를 확인할 수 있습니다.
# (https://keraskorea.github.io/posts/2018-10-23-keras_autoencoder/)
#
# 이번 프로젝트에서 사용될 특징은 데이터의 특징을 추출하는 것입니다. ![캡처.PNG](data:image/png;base64,...)

# %% [markdown]
# 위 사진에서 확인할 수 있듯이 Encoder를 통해서 이미지를 특징점을 가지는 global descriptor로 압축하는 것이 가능합니다. 아래의 간단한 모델을 통해서 확인해 보겠습니다.

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
from keras.models import Model
from keras import backend as K

input_img = Input(shape=(150, 150, 3))  

x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((3, 3), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((5, 5), padding='same')(x)
x = Flatten()(x)
encoded = Dense(100, activation='relu')(x)

# Encoder model
encoder = Model(input_img, encoded)
#encoder.summary()

Decoded_img = Input(shape=(100,))
x = Dense(5*5*8)(Decoded_img)
x = Reshape((5,5,8))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((5, 5))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((3, 3))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)
decoder = Model(Decoded_img, decoded)
#decoder.summary()

x = encoder(input_img)
decoder_out = decoder(x)
autoencoder = Model(input_img, decoder_out)
autoencoder.summary()
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=["accuracy"] )

# %% [markdown]
# 위에서 생성한 모델을 (summer,fall), (summer,summer), (fall, summer), (fall, fall) 쌍으로 학습을 통해서 global desicriptor를 생성하는 것이 가능합니다.
#
# 아래에서는 (summer, summer)를 조건으로 학습을 진행합니다.

# %%
autoencoder.fit(train_summer, train_summer, batch_size = 10, epochs= 10)

# %% [markdown]
# ### 5-1.descriptor 추출
# 위에서 학습한 autoencder의 encdoer를 이용해서 global descriptor를 추출합니다.

# %%
summer_feature = encoder.predict(train_summer)
fall_feature = encoder.predict(train_fall)

print("summer_feature size = ", summer_feature.shape)
print("fall_feature size = ", fall_feature.shape)

# %% [markdown]
# ### 5-2.similarit matrix(유사도 행렬) 생성
# 유사도 행렬은 두 개의 계절의 이미지에서 서로 유사한 이미지의 유사도를 수식으로 표현한 행렬입니다. 이번 프로젝트에서는 cosine distance를 이용해 결과를 확인할 것입니다.
#
# summer_descriptor = A, fall_descriptor = B
#
# cosine distance = ( A * B) / (||A|| ||B||)

# %%
def cosine_distance(a, b):
    return abs(np.dot(a, b) / (np.linalg.norm(a) * (np.linalg.norm(b))))

# %% [markdown]
# 위에서 생성한 cosine distance를 이용해 각가의 summer 이미지와 fall 이미지 사이의 유사도를 구하고 matrix로 생성합니다. 0~1 사이의 값으로 균등하게 하기위해서 scaling을 적용합니다.

# %%
def similarity_matrix(a,b):
    w_len, h_len = a.shape[0], b.shape[0]
    matrix = np.zeros((w_len, h_len))

    for i in range(w_len):
        for j in range(h_len):
            matrix[i][j] = cosine_distance(a[i],b[j])

    return matrix

def scaling(matrix):
    result = (matrix -np.min(matrix))/(np.max(matrix) - np.min(matrix))

    return result

# %% [markdown]
# similarity matrix의 크기를 250x250으로 생성하기 위해서 0~250까지의 이미지의 discriptor를 이용합니다. 확인 결과 아래와 같은 heatmap이 출력됩니다.

# %%
import seaborn as sns
summer_feature = summer_feature[:250]
fall_feature = fall_feature[:250]


matrix = similarity_matrix(summer_feature, fall_feature)
matrix = scaling(matrix)

sns.heatmap(matrix)

# %% [markdown]
# 출력된 결과를 확인하면 대각선으로 밝은 선이 생성되는 것을 확인할 수 있습니다. 하지만 유사도의 차이가 확연하게 차이가 나지 않아서 다른 부분에서도 밝은 부분이 나오는 것을 확인할 수 있습니다.

# %% [markdown]
# ### 5-3.Precision-Recall curve, f1_score
# 모델의 성능을 평가하는 지표로 사용되는 방법입니다. 자세한 설명은 아래의 링크를 통해서 확인하시면 됩니다.
# (https://sumniya.tistory.com/26)
#
# GroudTruth와 생성한 similarity matrix를 비교해 평가합니다.
#
# Ground Truth는 대각행렬이기 때문에 np.eye를 통해서 생성합니다. 그 후 아래의 함수를 통해서 Precision-Recall curve를 생성합니다.

# %%
# Precision-Recall function
import sklearn.metrics as metrics

def Precision_Recall(similarity):
    thresholds = [i / 1000 for i in range(1000)]
    matrix_shape = len(matrix)
    GT = np.eye(matrix_shape)
    pr_s = []
    re_s = []
    f1_s = []

    for threshold in thresholds:
        test_matrix = similarity > threshold

        right = np.sum(test_matrix * GT == 1)
        precision = right / np.sum(test_matrix)
        recall = right/ np.sum(GT)
        f1 = 2 * precision*recall/(precision+recall)

        pr_s.append(precision)
        re_s.append(recall)
        f1_s.append(f1)

    return pr_s, re_s, f1_s

# %%
Precision, Recall, F1 = Precision_Recall(matrix)

plt.plot(Recall,Precision,'-r',label="CAE")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Recall-Precision curve")
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %% [markdown]
# 출력 결과 위와 같은 결과를 확인할 수 있습니다. Precision-recall을 통해서 결과를 확인하는 경우, 그래프가 완만하게 감소하며 recall이 커짐에 따라서 precision이 큰 값을 유지하는 경우 좋은 성능을 가진 모델입니다.

# %% [markdown]
# f1_score의 경우 precsion,recall을 이용한 아래와 같은 식을 통한 함수입니다.
#
# f1_score = 2* (Precision * Recall) /(Precision + Recall)
#
# 이중에서 max값을 이용해 결과를 평가하겠습니다.

# %%
# f1_score_function
f1_max = max(F1)
print("f1_max = ", round(f1_max,4))

# %% [markdown]
# ## 6.vgg16을 통한 전이학습
# 이번 프로젝트의 목적은 여러분들이 모델을 생성하거나,컴퓨터 비전 기술 등을 이용해 계절이 다른 장소의 위치를 확인하는 것입니다.
# 그러므로 간단한 예시로 vgg16을 통해서 유사도행렬까지만 출력하겠습니다.
#
# 아래의 링크를 통해서 자세하게 확인할 수 있습니다.
#
# https://www.pyimagesearch.com/2020/11/30/siamese-networks-with-keras-tensorflow-and-deep-learning/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 각각의 계절의 이미지를 쌍으로 묶어서 입력으로 생성합니다. 이미지 쌍을 생성할 때 동일한 위치의 이미지 쌍과 다른 위치의 이미지 쌍을 생성합니다.
#
# ConvNet 자리에 vgg16을 통해 생성한 모델을 이용해서 각각의 이미지의 discriptor을 생성하고 euclidean_distance을 통해서 유사도를 비교합니다.

# %%
import keras
from keras import Model
from keras import models
from keras.layers import *
from keras.optimizers import *
import tensorflow as tf

# %% [markdown]
# 먼저 아래의 코드를 이용해 keras에서 제공하는 pretrained vgg16을 불러옵니다.

# %%
from tensorflow.keras.applications.vgg16 import VGG16
vggmodel = VGG16(weights='imagenet', include_top=False, input_shape=(150,150,3))

# %%
vggmodel.summary()

# %% [markdown]
# 이미 학습된 모델이기 때문에 전체 모델을 학습을 진행할 때 가중치를 고정하기 위해서 아래와 같이 trainable = False로 변경합니다.

# %%
for layers in (vggmodel.layers)[:19]:
    layers.trainable = False

for i, layer in enumerate(vggmodel.layers):
    print(i,":", 'layer name = ',layer.name, "     trainable = ", layer.trainable)

# %% [markdown]
# 모델의 이미지와 동일한 코드를 생성합니다. vgg16을 discriptor 추출기로 사용합니다.
#
# loss를 생성된 discriptor 간의 차이를 euclidean_distance를 이용하기 위해서 아래와 같이 custom_loss를 생성합니다.
#
# make_pair 함수는 각각의 계절의 이미지를 동일한 위치와, 랜덤한 동일하지 않은 위치의 쌍으로 생성합니다.

# %%
from tensorflow.keras.layers import Input, Dropout, Dense, Flatten
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K

def build_siamese_model(inputShape, embeddingDim=100):
    inputs = Input(inputShape)
    x = vggmodel(inputs)
    x = Flatten()(x)
    x = Dense(4096, activation='relu', input_dim=4 * 4 * 512)(x)
    x = Dropout(0.5)(x)
    outputs = Dense(100)(x)
    model = Model(inputs,outputs)

    return model

def euclidean_distance(vectors):
    (featsA, featsB) = vectors

    sumSquared = K.sum(K.square(featsA- featsB), axis=1, keepdims=True)

    return K.sqrt(K.maximum(sumSquared, K.epsilon()))

def make_pairs(summer, fall, Mode=0):

    pairImages = []
    pairLabels = []

    numPlace = np.arange(len(summer))

    for idx in numPlace:
        currentImage = summer[idx]
        posImage = fall[idx]

        pairImages.append([currentImage,posImage])
        pairLabels.append([1])

    if Mode == 1:
        for idx in numPlace:
            currentImage = summer[idx]

            for num in range(3):
                negIdx = np.where(numPlace != idx)[0]
                negImage = fall[np.random.choice(negIdx)]
                pairImages.append([currentImage,negImage])
                pairLabels.append([0])

    return (np.array(pairImages), np.array(pairLabels))

# %%
from tensorflow.keras.layers import Lambda,Input, Dropout, Dense, Flatten
from tensorflow.keras.models import Model
imgA = Input(shape=(150,150,3))
imgB = Input(shape=(150,150,3))
#descriptorExtractor라는 모델 객체를 만든다.
descriptorExtractor = build_siamese_model((150,150,3))
#이제 해당 모델의 출력으로 각 global descriptor를 출력한다.
descsA = descriptorExtractor(imgA)
descsB = descriptorExtractor(imgB)

#람다(lamda)레이어를 통해서, descriptor 사이의 유클리드 거리를 구한다.
distance = Lambda(euclidean_distance)([descsA,descsB])
#이제 출력을 sigmoid를 사용하여 0과 1사이의 출력이 되도록한다.
outputs = Dense(1, activation='sigmoid')(distance)

#최종적으로 입력과 출력을 등록하여 모델 객체를 생성한다.
final_model = Model(inputs=[imgA, imgB], outputs=outputs)

# %% [markdown]
# ![샴sim.PNG](data:image/png;base64,...)

# %% [markdown]
# 모델을 이용해 결과를 확인한 경우 CAE보다 더 명확한 결과가 생성되는 것을 확인할 수 있습니다.

# %% [markdown]
# # 7.각자의 모델, 또는 방법을 이용한 장소 인식
# 이제 여러분만의 장소 인식 모델을 생성해 결과를 평가하겠습니다.
#
# 기한 : 5.16 ~ 5.29
# (추가제출 기한은 6시간을 추가로 드리겠습니다. 단, 감점이 있을 것입니다.)
#
# 평가 방법: f1_score을 통해서 결과를 확인할 것입니다.
# 여러분들은 각자의 방법으로 descriptor를 추출해서 similarit matrix를 생성해서 보내주시면됩니다.
# test_set으로 사용될 데이터 셋은 마감일 2일 전에 업로드하겠습니다. 단, Ground_truth가 대각선이 아닌 랜덤하게 섞여있는 데이터셋입니다. 출력 결과가 대각선이 아니게 나올 것입니다.
#
#
#
#
# 최종 제출본은 'similarity_matrix.npy', 'MiniProj#3.ipynb', 프로젝트 보고서를 압축한 '이름_학번.zip'를 업로드하시면 됩니다.

# %% [markdown]
# ### 2020741051 이재원

# %%
import numpy as np

train_summer_temp = np.load("./place_recognition/summer_train_150.npy")
train_fall_temp = np.load("./place_recognition/fall_train_150.npy")
print("summer image shape is ", train_summer_temp.shape)
print("fall image shape is ", train_fall_temp.shape)

train_summer = train_summer_temp[:2900]
train_fall   = train_fall_temp[:2900]
valid_summer = train_summer_temp[2900:3000]
valid_fall   = train_fall_temp[2900:3000]

print("summer image shape is ", train_summer.shape)
print("fall image shape is ", train_fall.shape)

print("Valid summer image shape is ", valid_summer.shape)
print("Valid  fall image shape is ", valid_fall.shape)

# train_summer = train_summer / 255.0
# train_fall = train_fall/255.0

train_summer_norm = train_summer / 255.0
train_fall_norm   = train_fall   / 255.0
valid_summer_norm = valid_summer / 255.0
valid_fall_norm   = valid_fall   / 255.0
# Out:
# summer image shape is  (3000, 150, 150, 3)
# fall image shape is  (3000, 150, 150, 3)
# summer image shape is  (2900, 150, 150, 3)
# fall image shape is  (2900, 150, 150, 3)
# Valid summer image shape is  (100, 150, 150, 3)
# Valid  fall image shape is  (100, 150, 150, 3)

# %%
print(train_summer_norm.shape)
print(train_fall_norm.shape)
print(valid_summer_norm.shape)
print(valid_fall_norm.shape)
# Out:
# (2900, 150, 150, 3)
# (2900, 150, 150, 3)
# (100, 150, 150, 3)
# (100, 150, 150, 3)

# %% [markdown]
# ### My Model

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape, Dropout
from keras.models import Model
from keras import backend as K


input_img = Input(shape=(150, 150, 3))  


x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((3, 3), padding='same')(x)

x = Flatten()(x)
x =  Dense(2048, activation='relu')(x)
encoded = Dense(1024, activation='relu')(x)

# Encoder model
encoder = Model(input_img, encoded)
encoder.summary()

Decoded_img = Input(shape=(1024,))   # Z
x = Dense(2048, activation='relu')(Decoded_img)
x = Dense(5000)(x)
x = Reshape((25,25,8))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((3, 3))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)
decoder = Model(Decoded_img, decoded)
decoder.summary()

x = encoder(input_img)
decoder_out = decoder(x)
autoencoder = Model(input_img, decoder_out)
autoencoder.summary()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"] )
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 40000)             0
#
#  dense (Dense)               (None, 2048)              81922048
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
# =================================================================
# Total params: 84,039,616
# Trainable params: 84,039,616
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1024)]            0
#
#  dense_2 (Dense)             (None, 2048)              2099200
#
#  dense_3 (Dense)             (None, 5000)              10245000
#
#  reshape (Reshape)           (None, 25, 25, 8)         0
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 64)        4672
#
#  up_sampling2d (UpSampling2D  (None, 75, 75, 64)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 32)        18464
#
#  up_sampling2d_1 (UpSampling  (None, 150, 150, 32)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 150, 150, 3)       867
#
# =================================================================
# Total params: 12,368,203
# Trainable params: 12,368,203
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  model (Functional)          (None, 1024)              84039616
#
#  model_1 (Functional)        (None, 150, 150, 3)       12368203
#
# =================================================================
# Total params: 96,407,819
# Trainable params: 96,407,819
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
autoencoder.fit(train_summer_norm, train_fall_norm, batch_size = 32, epochs= 100, validation_data=(valid_summer_norm,valid_fall_norm))
# Out:
# Epoch 1/100
# 91/91 [==============================] - 12s 57ms/step - loss: 0.5707 - accuracy: 0.5921 - val_loss: 0.5599 - val_accuracy: 0.6736
# Epoch 2/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.5368 - accuracy: 0.7126 - val_loss: 0.5429 - val_accuracy: 0.7069
# Epoch 3/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.5276 - accuracy: 0.7380 - val_loss: 0.5401 - val_accuracy: 0.7195
# Epoch 4/100
# 91/91 [==============================] - 5s 50ms/step - loss: 0.5223 - accuracy: 0.7486 - val_loss: 0.5311 - val_accuracy: 0.7203
# Epoch 5/100
# 91/91 [==============================] - 4s 49ms/step - loss: 0.5188 - accuracy: 0.7560 - val_loss: 0.5298 - val_accuracy: 0.7191
# Epoch 6/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5164 - accuracy: 0.7616 - val_loss: 0.5269 - val_accuracy: 0.7183
# Epoch 7/100
# 91/91 [==============================] - 5s 59ms/step - loss: 0.5145 - accuracy: 0.7672 - val_loss: 0.5256 - val_accuracy: 0.7187
# Epoch 8/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.5129 - accuracy: 0.7705 - val_loss: 0.5265 - val_accuracy: 0.7220
# Epoch 9/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.5118 - accuracy: 0.7749 - val_loss: 0.5246 - val_accuracy: 0.7225
# Epoch 10/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5107 - accuracy: 0.7788 - val_loss: 0.5249 - val_accuracy: 0.7205
# Epoch 11/100
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5097 - accuracy: 0.7819 - val_loss: 0.5242 - val_accuracy: 0.7234
# Epoch 12/100
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5090 - accuracy: 0.7827 - val_loss: 0.5248 - val_accuracy: 0.7289
# Epoch 13/100
# 91/91 [==============================] - 5s 58ms/step - loss: 0.5081 - accuracy: 0.7850 - val_loss: 0.5245 - val_accuracy: 0.7258
# Epoch 14/100
# 91/91 [==============================] - 5s 58ms/step - loss: 0.5075 - accuracy: 0.7852 - val_loss: 0.5244 - val_accuracy: 0.7302
# Epoch 15/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.5070 - accuracy: 0.7879 - val_loss: 0.5246 - val_accuracy: 0.7298
# Epoch 16/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5065 - accuracy: 0.7871 - val_loss: 0.5242 - val_accuracy: 0.7227
# Epoch 17/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5061 - accuracy: 0.7871 - val_loss: 0.5244 - val_accuracy: 0.7302
# Epoch 18/100
# 91/91 [==============================] - 5s 59ms/step - loss: 0.5057 - accuracy: 0.7873 - val_loss: 0.5240 - val_accuracy: 0.7281
# Epoch 19/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5053 - accuracy: 0.7881 - val_loss: 0.5246 - val_accuracy: 0.7222
# Epoch 20/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5049 - accuracy: 0.7877 - val_loss: 0.5247 - val_accuracy: 0.7254
# Epoch 21/100
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5046 - accuracy: 0.7883 - val_loss: 0.5245 - val_accuracy: 0.7238
# Epoch 22/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5042 - accuracy: 0.7879 - val_loss: 0.5251 - val_accuracy: 0.7313
# Epoch 23/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5040 - accuracy: 0.7880 - val_loss: 0.5248 - val_accuracy: 0.7180
# Epoch 24/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.5037 - accuracy: 0.7884 - val_loss: 0.5256 - val_accuracy: 0.7231
# Epoch 25/100
# 91/91 [==============================] - 5s 51ms/step - loss: 0.5033 - accuracy: 0.7888 - val_loss: 0.5255 - val_accuracy: 0.7304
# Epoch 26/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.5029 - accuracy: 0.7880 - val_loss: 0.5246 - val_accuracy: 0.7240
# Epoch 27/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5027 - accuracy: 0.7889 - val_loss: 0.5249 - val_accuracy: 0.7244
# Epoch 28/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5024 - accuracy: 0.7887 - val_loss: 0.5253 - val_accuracy: 0.7295
# Epoch 29/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5022 - accuracy: 0.7896 - val_loss: 0.5254 - val_accuracy: 0.7207
# Epoch 30/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5021 - accuracy: 0.7906 - val_loss: 0.5259 - val_accuracy: 0.7218
# Epoch 31/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5018 - accuracy: 0.7901 - val_loss: 0.5260 - val_accuracy: 0.7278
# Epoch 32/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5016 - accuracy: 0.7918 - val_loss: 0.5267 - val_accuracy: 0.7210
# Epoch 33/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5013 - accuracy: 0.7911 - val_loss: 0.5253 - val_accuracy: 0.7253
# Epoch 34/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5012 - accuracy: 0.7910 - val_loss: 0.5260 - val_accuracy: 0.7157
# Epoch 35/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5011 - accuracy: 0.7915 - val_loss: 0.5258 - val_accuracy: 0.7252
# Epoch 36/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5008 - accuracy: 0.7922 - val_loss: 0.5256 - val_accuracy: 0.7182
# Epoch 37/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5006 - accuracy: 0.7934 - val_loss: 0.5263 - val_accuracy: 0.7193
# Epoch 38/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.5005 - accuracy: 0.7943 - val_loss: 0.5268 - val_accuracy: 0.7211
# Epoch 39/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5003 - accuracy: 0.7935 - val_loss: 0.5259 - val_accuracy: 0.7273
# Epoch 40/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5001 - accuracy: 0.7949 - val_loss: 0.5265 - val_accuracy: 0.7227
# Epoch 41/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.5000 - accuracy: 0.7955 - val_loss: 0.5259 - val_accuracy: 0.7215
# Epoch 42/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4999 - accuracy: 0.7952 - val_loss: 0.5261 - val_accuracy: 0.7210
# Epoch 43/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4998 - accuracy: 0.7961 - val_loss: 0.5275 - val_accuracy: 0.7232
# Epoch 44/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4998 - accuracy: 0.7958 - val_loss: 0.5265 - val_accuracy: 0.7233
# Epoch 45/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4997 - accuracy: 0.7966 - val_loss: 0.5262 - val_accuracy: 0.7195
# Epoch 46/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4996 - accuracy: 0.7963 - val_loss: 0.5273 - val_accuracy: 0.7268
# Epoch 47/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4995 - accuracy: 0.7967 - val_loss: 0.5268 - val_accuracy: 0.7227
# Epoch 48/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4993 - accuracy: 0.7965 - val_loss: 0.5264 - val_accuracy: 0.7139
# Epoch 49/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4992 - accuracy: 0.7968 - val_loss: 0.5268 - val_accuracy: 0.7224
# Epoch 50/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4992 - accuracy: 0.7971 - val_loss: 0.5271 - val_accuracy: 0.7194
# Epoch 51/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4993 - accuracy: 0.7989 - val_loss: 0.5269 - val_accuracy: 0.7226
# Epoch 52/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4993 - accuracy: 0.7971 - val_loss: 0.5273 - val_accuracy: 0.7208
# Epoch 53/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4992 - accuracy: 0.7980 - val_loss: 0.5273 - val_accuracy: 0.7202
# Epoch 54/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4992 - accuracy: 0.7978 - val_loss: 0.5269 - val_accuracy: 0.7174
# Epoch 55/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4990 - accuracy: 0.7990 - val_loss: 0.5266 - val_accuracy: 0.7216
# Epoch 56/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4988 - accuracy: 0.7989 - val_loss: 0.5281 - val_accuracy: 0.7201
# Epoch 57/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4986 - accuracy: 0.7989 - val_loss: 0.5273 - val_accuracy: 0.7198
# Epoch 58/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4986 - accuracy: 0.7998 - val_loss: 0.5264 - val_accuracy: 0.7242
# Epoch 59/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4985 - accuracy: 0.8000 - val_loss: 0.5270 - val_accuracy: 0.7217
# Epoch 60/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4985 - accuracy: 0.7995 - val_loss: 0.5274 - val_accuracy: 0.7149
# Epoch 61/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4984 - accuracy: 0.7995 - val_loss: 0.5276 - val_accuracy: 0.7205
# Epoch 62/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4984 - accuracy: 0.8010 - val_loss: 0.5275 - val_accuracy: 0.7162
# Epoch 63/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4985 - accuracy: 0.7999 - val_loss: 0.5273 - val_accuracy: 0.7165
# Epoch 64/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.4985 - accuracy: 0.8004 - val_loss: 0.5273 - val_accuracy: 0.7156
# Epoch 65/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4984 - accuracy: 0.7999 - val_loss: 0.5270 - val_accuracy: 0.7205
# Epoch 66/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4984 - accuracy: 0.8010 - val_loss: 0.5282 - val_accuracy: 0.7186
# Epoch 67/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4985 - accuracy: 0.8014 - val_loss: 0.5267 - val_accuracy: 0.7142
# Epoch 68/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.4984 - accuracy: 0.8014 - val_loss: 0.5270 - val_accuracy: 0.7246
# Epoch 69/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4983 - accuracy: 0.8000 - val_loss: 0.5272 - val_accuracy: 0.7219
# Epoch 70/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4981 - accuracy: 0.8018 - val_loss: 0.5272 - val_accuracy: 0.7214
# Epoch 71/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4980 - accuracy: 0.8019 - val_loss: 0.5278 - val_accuracy: 0.7148
# Epoch 72/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4979 - accuracy: 0.8025 - val_loss: 0.5267 - val_accuracy: 0.7212
# Epoch 73/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4978 - accuracy: 0.8022 - val_loss: 0.5278 - val_accuracy: 0.7169
# Epoch 74/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4978 - accuracy: 0.8029 - val_loss: 0.5275 - val_accuracy: 0.7217
# Epoch 75/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4978 - accuracy: 0.8025 - val_loss: 0.5275 - val_accuracy: 0.7123
# Epoch 76/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4978 - accuracy: 0.8034 - val_loss: 0.5269 - val_accuracy: 0.7185
# Epoch 77/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4979 - accuracy: 0.8028 - val_loss: 0.5272 - val_accuracy: 0.7175
# Epoch 78/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4979 - accuracy: 0.8033 - val_loss: 0.5269 - val_accuracy: 0.7136
# Epoch 79/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4981 - accuracy: 0.8042 - val_loss: 0.5275 - val_accuracy: 0.7153
# Epoch 80/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4981 - accuracy: 0.8038 - val_loss: 0.5270 - val_accuracy: 0.7241
# Epoch 81/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4981 - accuracy: 0.8041 - val_loss: 0.5280 - val_accuracy: 0.7190
# Epoch 82/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4980 - accuracy: 0.8030 - val_loss: 0.5284 - val_accuracy: 0.7199
# Epoch 83/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4978 - accuracy: 0.8052 - val_loss: 0.5279 - val_accuracy: 0.7187
# Epoch 84/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.4976 - accuracy: 0.8048 - val_loss: 0.5271 - val_accuracy: 0.7202
# Epoch 85/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.4975 - accuracy: 0.8050 - val_loss: 0.5277 - val_accuracy: 0.7164
# Epoch 86/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4975 - accuracy: 0.8055 - val_loss: 0.5279 - val_accuracy: 0.7149
# Epoch 87/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.4974 - accuracy: 0.8052 - val_loss: 0.5275 - val_accuracy: 0.7144
# Epoch 88/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.4974 - accuracy: 0.8063 - val_loss: 0.5274 - val_accuracy: 0.7192
# Epoch 89/100
# 91/91 [==============================] - 5s 53ms/step - loss: 0.4974 - accuracy: 0.8064 - val_loss: 0.5275 - val_accuracy: 0.7205
# Epoch 90/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.4974 - accuracy: 0.8062 - val_loss: 0.5277 - val_accuracy: 0.7187
# Epoch 91/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.4975 - accuracy: 0.8059 - val_loss: 0.5276 - val_accuracy: 0.7191
# Epoch 92/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.4975 - accuracy: 0.8064 - val_loss: 0.5277 - val_accuracy: 0.7189
# Epoch 93/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.4976 - accuracy: 0.8062 - val_loss: 0.5279 - val_accuracy: 0.7144
# Epoch 94/100
# 91/91 [==============================] - 5s 54ms/step - loss: 0.4977 - accuracy: 0.8068 - val_loss: 0.5284 - val_accuracy: 0.7128
# Epoch 95/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.4977 - accuracy: 0.8074 - val_loss: 0.5278 - val_accuracy: 0.7221
# Epoch 96/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.4977 - accuracy: 0.8071 - val_loss: 0.5284 - val_accuracy: 0.7149
# Epoch 97/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.4977 - accuracy: 0.8071 - val_loss: 0.5282 - val_accuracy: 0.7162
# Epoch 98/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.4976 - accuracy: 0.8077 - val_loss: 0.5274 - val_accuracy: 0.7145
# Epoch 99/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.4975 - accuracy: 0.8078 - val_loss: 0.5277 - val_accuracy: 0.7184
# Epoch 100/100
# 91/91 [==============================] - 5s 52ms/step - loss: 0.4973 - accuracy: 0.8086 - val_loss: 0.5272 - val_accuracy: 0.7165

# %%
summer_feature = encoder.predict(train_summer)
fall_feature = encoder.predict(train_fall)

print("summer_feature size = ", summer_feature.shape)
print("fall_feature size = ", fall_feature.shape)
# Out:
# summer_feature size =  (2900, 1024)
# fall_feature size =  (2900, 1024)

# %%
def cosine_distance(a, b):
    return abs(np.dot(a, b) / (np.linalg.norm(a) * (np.linalg.norm(b))))

def similarity_matrix(a,b):
    w_len, h_len = a.shape[0], b.shape[0]
    matrix = np.zeros((w_len, h_len))

    for i in range(w_len):
        for j in range(h_len):
            matrix[i][j] = cosine_distance(a[i],b[j])

    return matrix

def scaling(matrix):
    result = (matrix -np.min(matrix))/(np.max(matrix) - np.min(matrix))

    return result

# %%
import seaborn as sns
summer_feature = summer_feature[:250]
fall_feature = fall_feature[:250]


matrix = similarity_matrix(summer_feature, fall_feature)
matrix = scaling(matrix)

sns.heatmap(matrix)
# Out:
# <AxesSubplot:>

# %%
# Precision-Recall function
import sklearn.metrics as metrics
import matplotlib.pyplot as plt 

def Precision_Recall(similarity):
    thresholds = [i / 1000 for i in range(1000)]
    matrix_shape = len(matrix)
    GT = np.eye(matrix_shape)
    pr_s = []
    re_s = []
    f1_s = []

    for threshold in thresholds:
        test_matrix = similarity > threshold

        right = np.sum(test_matrix * GT == 1)
        precision = right / np.sum(test_matrix)
        recall = right/ np.sum(GT)
        f1 = 2 * precision*recall/(precision+recall)

        pr_s.append(precision)
        re_s.append(recall)
        f1_s.append(f1)

    return pr_s, re_s, f1_s

Precision, Recall, F1 = Precision_Recall(matrix)

plt.plot(Recall,Precision,'-r',label="CAE")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Recall-Precision curve")
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %%
# f1_score_function
f1_max = max(F1)
print("f1_max = ", round(f1_max,4))
# Out:
# f1_max =  0.7182

# %% [markdown]
# ### Save

# %%
import tensorflow as tf
from keras.models import save_model, load_model
encoder.save('./place_recognition/train/encoder.h5')

# %%
# matrix 저장하기
import numpy as np
np.save('./place_recognition/train/similarity_matrix.npy',matrix)

# %% [markdown]
# ### Test Set

# %%
test_summer = np.load("./place_recognition/test_summer.npy")
test_fall = np.load("./place_recognition/test_fall.npy")
print("test summer image shape is ", test_summer.shape)
print("test fall image shape is ", test_fall.shape)
# Out:
# test summer image shape is  (250, 150, 150, 3)
# test fall image shape is  (250, 150, 150, 3)

# %%
test_summer_feature = encoder.predict(test_summer)
test_fall_feature = encoder.predict(test_fall)

print("test_summer_feature size = ", test_summer_feature.shape)
print("test_fall_feature size = ", test_fall_feature.shape)
# Out:
# test_summer_feature size =  (250, 1024)
# test_fall_feature size =  (250, 1024)

# %%
test_matrix = similarity_matrix(test_summer_feature, test_fall_feature)
test_matrix = scaling(test_matrix)

sns.heatmap(test_matrix)
# Out:
# <AxesSubplot:>

# %%
test_Precision, test_Recall, test_F1 = Precision_Recall(test_matrix)

plt.plot(test_Recall,test_Precision,'-r',label="CAE")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Recall-Precision curve")
plt.legend(loc='upper right')
plt.grid()
plt.show()
# Out:
# C:\Users\LeeJaeWon\AppData\Local\Temp\ipykernel_23016\1058705778.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = 2 * precision*recall/(precision+recall)

# %%
# f1_score_function
test_f1_max = max(test_F1)
print("f1_max = ", round(test_f1_max,4))
# Out:
# f1_max =  0.0081

# %%
import tensorflow as tf
from keras.models import save_model, load_model
encoder.save('./place_recognition/test/encoder.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# matrix 저장하기
import numpy as np
np.save('./place_recognition/test/similarity_matrix_test.npy',test_matrix)

# %% [markdown]
# ## 저장 확인

# %%
matrix3 = np.load('./place_recognition/test/similarity_matrix_test.npy')

# %%
# Precision-Recall function
import sklearn.metrics as metrics
import matplotlib.pyplot as plt 

def Precision_Recall(similarity):
    thresholds = [i / 1000 for i in range(1000)]
    matrix_shape = len(matrix3)
    GT = np.eye(matrix_shape)
    pr_s = []
    re_s = []
    f1_s = []

    for threshold in thresholds:
        test_matrix = similarity > threshold

        right = np.sum(test_matrix * GT == 1)
        precision = right / np.sum(test_matrix)
        recall = right/ np.sum(GT)
        f1 = 2 * precision*recall/(precision+recall)

        pr_s.append(precision)
        re_s.append(recall)
        f1_s.append(f1)

    return pr_s, re_s, f1_s

Precision, Recall, F1 = Precision_Recall(matrix3)

plt.plot(Recall,Precision,'-r',label="CAE")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Recall-Precision curve")
plt.legend(loc='upper right')
plt.grid()
plt.show()
# Out:
# C:\Users\LeeJaeWon\AppData\Local\Temp\ipykernel_23016\1451737345.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   f1 = 2 * precision*recall/(precision+recall)

# %%
test_matrix = similarity_matrix(test_summer_feature, test_fall_feature)
test_matrix = scaling(matrix3)

sns.heatmap(test_matrix)
# Out:
# <AxesSubplot:>
